# %% [markdown]
# ### Imports

# %%
import main_var
env = "test_new/"
mv = main_var.main_var(env=env)

from article_scraping_lib import *
from article_parsing_lib import *
from openai_module_lib import *
from embedding_keyword_module_lib import *
from utils_art import *


max_num = 10000000
step_pct=0.005
df = loop_scraping(9,'2000-01-01','2024-01-01',sampling_1=5,sampling_2=5,save_steps=True,save_final=True,display=True)
df2 =  filterQuerryDataset(df,150,10,True,True,True)
df_querry = readArticleFileTable(index_from=0,index_to=max_num,save_articles=True,save_final=True,save_steps=True,display_df=True,step_pct=step_pct,add_nlp=2,filtered_input_df=True)
df_join = joinQuerryAndParse(save=True,remove_invalid=True,display=True,filtered_input_df=True)
df_embd = mainGeneration(True,False,10,max_num,7500,1000,True,True,True,step_pct)
emb_mat = extractEmbeddingFromFile(max_num)
df_key = mainKeywordWF(max_num,100)
df_final = mainJoinOut()
# Out:
# IMPORT : main_var
# IMPORT : utils_art
# IMPORT : text_analysis
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# IMPORT : article_scraping_lib
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# IMPORT : article_parsing_lib
# IMPORT : openai_module_lib

# %%
# df = openDFcsv(mv.query_path,mv.query_filename)
# df3 = selectOnDf(df2,"","")
# plotDFstatisticsQuerry(df,70)
# displayStats(df)
# saveDFcsv(df3,mv.query_path,mv.query_filename)



# df = loop_scraping(9,'1999-03-27','2024-03-19',sampling_1=5,sampling_2=5,save_steps=True,save_final=True,display=True)
# plotDFstatisticsQuerry(df,70)
# displayStats(df)

# df = openDFcsv(mv.query_path,mv.query_filename)
# df2 =  filterQuerryDataset(df,150,10,True,True,True)
# plotDFstatisticsQuerry(df2,70,True)
# displayStats(df2)

# df = openDFcsv(mv.query_path,mv.query_filename)
df_querry = readArticleFileTable(index_from=0,index_to=99999999999,save_articles=True,save_final=True,save_steps=True,display_df=True,step_pct=0.005,add_nlp=2,filtered_input_df=True)
# df_join = joinQuerryAndParse(save=True,remove_invalid=True,display=True,filtered_input_df=True)
# df_embd = mainGeneration(True,False,10,99999999,7500,9999,True,True,True,0.1)
# emb_mat = extractEmbeddingFromFile(999999999)
# df_key = mainKeywordWF(99999999999,100)
# df_final = mainJoinOut()
# Out:
#  - Loadind Article #0   (Valid Article)
#  - Loadind Article #1   (Valid Article)
#  - Loadind Article #2   (Not valid : Dict could not be read)
#  - Loadind Article #3   (Valid Article)
#  - Loadind Article #4   (Valid Article)
#  - Loadind Article #5   (Valid Article)
#  - Loadind Article #6   (Valid Article)
#  - Loadind Article #7   (Valid Article)
#  - Loadind Article #8   (Valid Article)
#  - Loadind Article #9   (Valid Article)
#  - Loadind Article #10   (Not valid : Dict could not be read)
#  - Loadind Article #11   (Valid Article)
#  - Loadind Article #12   (Valid Article)
#  - Loadind Article #13   (Valid Article)
#  - Loadind Article #14   (Valid Article)
#  - Loadind Article #15   (Valid Article)
#  - Loadind Article #16   (Valid Article)
#  - Loadind Article #17   (Valid Article)
#  - Loadind Article #18   (Valid Article)
#  - Loadind Article #19   (Valid Article)
#  - Loadind Article #20   (Valid Article)
#  - Loadind Article #21   (Valid Article)
#  - Loadind Article #22   (Valid Article)
#  - Loadind Article #23   (Valid Article)
#  - Loadind Article #24   (Valid Article)
#  - Loadind Article #25   (Not valid : Dict could not be read)
#  - Loadind Article #26   (Valid Article)
#  - Loadind Article #27   (Valid Article)
#  - Loadind Article #28   (Valid Article)
#  - Loadind Article #29   (Valid Article)
#  - Loadind Article #30   (Not valid : Dict could not be read)
#  - Loadind Article #31   (Valid Article)
#  - Loadind Article #32   (Not valid : Dict could not be read)
#  - Loadind Article #33   (Valid Article)
#  - Loadind Article #34   (Not valid : Dict could not be read)
#  - Loadind Article #35   (Valid Article)
#  - Loadind Article #36   (Valid Article)
#  - Loadind Article #37   (Valid Article)
#  - Loadind Article #38   (Valid Article)
#  - Loadind Article #39   (Valid Article)
#  - Loadind Article #40   (Not valid : Dict could not be read)
#  - Loadind Article #41   (Valid Article)
#  - Loadind Article #42   (Valid Article)
#  - Loadind Article #43   (Valid Article)
#  - Loadind Article #44   (Valid Article)
#  - Loadind Article #45   (Valid Article)
#  - Loadind Article #46   (Valid Article)
#  - Loadind Article #47   (Valid Article)
#  - Loadind Article #48   (Valid Article)
#  - Loadind Article #49   (Valid Article)
#  - Loadind Article #50   (Not valid : Dict could not be read)
#  - Loadind Article #51   (Valid Article)
#  - Loadind Article #52   (Valid Article)
#  - Loadind Article #53   (Valid Article)
#  - Loadind Article #54   (Valid Article)
#  - Loadind Article #55   (Valid Article)
#  - Loadind Article #56   (Not valid : Dict could not be read)
#  - Loadind Article #57   (Valid Article)
#  - Loadind Article #58   (Valid Article)
#  - Loadind Article #59   (Valid Article)
#  - Loadind Article #60   (Valid Article)
#  - Loadind Article #61   (Valid Article)
#  - Loadind Article #62   (Not valid : Dict could not be read)
#  - Loadind Article #63   (Valid Article)
#  - Loadind Article #64   (Valid Article)
#  - Loadind Article #65   (Valid Article)
#  - Loadind Article #66   (Valid Article)
#  - Loadind Article #67   (Valid Article)
#  - Loadind Article #68   (Valid Article)
#  - Loadind Article #69   (Valid Article)
#  - Loadind Article #70   (Valid Article)
#  - Loadind Article #71   (Valid Article)
#  - Loadind Article #72   (Valid Article)
#  - Loadind Article #73   (Valid Article)
#  - Loadind Article #74   (Valid Article)
#  - Loadind Article #75   (Valid Article)
#  - Loadind Article #76   (Valid Article)
#  - Loadind Article #77   (Valid Article)
#  - Loadind Article #78   (Valid Article)
#  - Loadind Article #79   (Valid Article)
#  - Loadind Article #80   (Valid Article)
#  - Loadind Article #81   (Valid Article)
#  - Loadind Article #82   (Valid Article)
#  - Loadind Article #83   (Valid Article)
#  - Loadind Article #84   (Valid Article)
#  - Loadind Article #85   (Valid Article)
#  - Loadind Article #86   (Valid Article)
#  - Loadind Article #87   (Not valid : Dict could not be read)
#  - Loadind Article #88   (Valid Article)
#  - Loadind Article #89   (Valid Article)
#  - Loadind Article #90   (Valid Article)
#  - Loadind Article #91   (Valid Article)
#  - Loadind Article #92   (Valid Article)
#  - Loadind Article #93   (Valid Article)
#  - Loadind Article #94   (Valid Article)
#  - Loadind Article #95   (Valid Article)
#  - Loadind Article #96   (Valid Article)
#  - Loadind Article #97   (Valid Article)
#  - Loadind Article #98   (Not valid : Dict could not be read)
#  - Loadind Article #99   (Valid Article)
#  - Loadind Article #100   (Valid Article)
#  - Loadind Article #101   (Valid Article)
#  - Loadind Article #102   (Valid Article)
#  - Loadind Article #103   (Valid Article)
#  - Loadind Article #104   (Valid Article)
#  - Loadind Article #105   (Valid Article)
#  - Loadind Article #106   (Valid Article)
#  - Loadind Article #107   (Valid Article)
#  - Loadind Article #108   (Not valid : Dict could not be read)
#  - Loadind Article #109   (Valid Article)
#  - Loadind Article #110   (Valid Article)
#  - Loadind Article #111   (Valid Article)
#  - Loadind Article #112   (Valid Article)
#  - Loadind Article #113   (Valid Article)
#  - Loadind Article #114   (Valid Article)
#  - Loadind Article #115   (Valid Article)
#  - Loadind Article #116   (Valid Article)
#  - Loadind Article #117   (Valid Article)
#  - Loadind Article #118   (Valid Article)
#  - Loadind Article #119   (Valid Article)
#  - Loadind Article #120   (Valid Article)
#  - Loadind Article #121   (Valid Article)
#  - Loadind Article #122   (Valid Article)
#  - Loadind Article #123   (Valid Article)
#  - Loadind Article #124   (Valid Article)
#  - Loadind Article #125   (Valid Article)
#  - Loadind Article #126   (Valid Article)
#  - Loadind Article #127   (Valid Article)
#  - Loadind Article #128   (Valid Article)
#  - Loadind Article #129   (Valid Article)
#  - Loadind Article #130   (Valid Article)
#  - Loadind Article #131   (Valid Article)
#  - Loadind Article #132   (Valid Article)
#  - Loadind Article #133   (Valid Article)
#  - Loadind Article #134   (Valid Article)
#  - Loadind Article #135   (Valid Article)
#  - Loadind Article #136   (Valid Article)
#  - Loadind Article #137   (Valid Article)
#  - Loadind Article #138   (Valid Article)
#  - Loadind Article #139   (Valid Article)
#  - Loadind Article #140   (Valid Article)
#  - Loadind Article #141   (Valid Article)
#  - Loadind Article #142   (Not valid : Dict could not be read)
#  - Loadind Article #143   (Valid Article)
#  - Loadind Article #144   (Valid Article)
#  - Loadind Article #145   (Not valid : Dict could not be read)
#  - Loadind Article #146   (Valid Article)
#  - Loadind Article #147   (Valid Article)
#  - Loadind Article #148   (Valid Article)
#  - Loadind Article #149   (Valid Article)
#  - Loadind Article #150   (Valid Article)
#  - Loadind Article #151   (Valid Article)
#  - Loadind Article #152   (Valid Article)
#  - Loadind Article #153   (Not valid : Dict could not be read)
#  - Loadind Article #154   (Valid Article)
#  - Loadind Article #155   (Valid Article)
#  - Loadind Article #156   (Valid Article)
#  - Loadind Article #157   (Valid Article)
#  - Loadind Article #158   (Valid Article)
#  - Loadind Article #159   (Valid Article)
#  - Loadind Article #160   (Valid Article)
#  - Loadind Article #161   (Not valid : Dict could not be read)
#  - Loadind Article #162   (Not valid : Dict could not be read)
#  - Loadind Article #163   (Valid Article)
#  - Loadind Article #164   (Valid Article)
#  - Loadind Article #165   (Not valid : Text empty)
#  - Loadind Article #166   (Valid Article)
#  - Loadind Article #167   (Valid Article)
#  - Loadind Article #168   (Valid Article)
#  - Loadind Article #169   (Valid Article)
#  - Loadind Article #170   (Valid Article)
#  - Loadind Article #171   (Valid Article)
#  - Loadind Article #172   (Valid Article)
#  - Loadind Article #173   (Valid Article)
#  - Loadind Article #174   (Not valid : Dict could not be read)
#  - Loadind Article #175   (Valid Article)
#  - Loadind Article #176   (Valid Article)
#  - Loadind Article #177   (Valid Article)
#  - Loadind Article #178   (Valid Article)
#  - Loadind Article #179   (Valid Article)
#  - Loadind Article #180   (Valid Article)
#  - Loadind Article #181   (Not valid : Dict could not be read)
#  - Loadind Article #182   (Valid Article)
#  - Loadind Article #183   (Not valid : Dict could not be read)
#  - Loadind Article #184   (Valid Article)
#  - Loadind Article #185   (Valid Article)
#  - Loadind Article #186   (Valid Article)
#  - Loadind Article #187   (Valid Article)
#  - Loadind Article #188   (Valid Article)
#  - Loadind Article #189   (Valid Article)
#  - Loadind Article #190   (Valid Article)
#  - Loadind Article #191   (Valid Article)
#  - Loadind Article #192   (Valid Article)
#  - Loadind Article #193   (Valid Article)
#  - Loadind Article #194   (Valid Article)
#  - Loadind Article #195   (Not valid : Dict could not be read)
#  - Loadind Article #196   (Valid Article)
#  - Loadind Article #197   (Valid Article)
#  - Loadind Article #198   (Valid Article)
#  - Loadind Article #199   (Valid Article)
#  - Loadind Article #200   (Not valid : Dict could not be read)
#  - Loadind Article #201   (Valid Article)
#  - Loadind Article #202   (Valid Article)
#  - Loadind Article #203   (Valid Article)
#  - Loadind Article #204   (Valid Article)
#  - Loadind Article #205   (Valid Article)
#  - Loadind Article #206   (Valid Article)
#  - Loadind Article #207   (Valid Article)
#  - Loadind Article #208   (Valid Article)
#  - Loadind Article #209   (Valid Article)
#  - Loadind Article #210   (Valid Article)
#  - Loadind Article #211   (Valid Article)
#  - Loadind Article #212   (Valid Article)
#  - Loadind Article #213   (Valid Article)
#  - Loadind Article #214   (Valid Article)
#  - Loadind Article #215   (Valid Article)
#  - Loadind Article #216   (Valid Article)
#  - Loadind Article #217   (Valid Article)
#  - Loadind Article #218   (Valid Article)
#  - Loadind Article #219   (Valid Article)
#  - Loadind Article #220   (Valid Article)
#  - Loadind Article #221   (Valid Article)
#  - Loadind Article #222   (Valid Article)
#  - Loadind Article #223   (Valid Article)
#  - Loadind Article #224   (Valid Article)
#  - Loadind Article #225   (Valid Article)
#  - Loadind Article #226   (Valid Article)
#  - Loadind Article #227   (Valid Article)
#  - Loadind Article #228   (Valid Article)
#  - Loadind Article #229   (Valid Article)
#  - Loadind Article #230   (Valid Article)
#  - Loadind Article #231   (Valid Article)
#  - Loadind Article #232   (Valid Article)
#  - Loadind Article #233   (Valid Article)
#  - Loadind Article #234   (Valid Article)
#  - Loadind Article #235   (Valid Article)
#  - Loadind Article #236   (Valid Article)
#  - Loadind Article #237   (Valid Article)
#  - Loadind Article #238   (Valid Article)
#  - Loadind Article #239   (Valid Article)
#  - Loadind Article #240   (Valid Article)
#  - Loadind Article #241   (Valid Article)
#  - Loadind Article #242   (Valid Article)
#  - Loadind Article #243   (Valid Article)
#  - Loadind Article #244   (Valid Article)
#  - Loadind Article #245   (Valid Article)
#  - Loadind Article #246   (Valid Article)
#  - Loadind Article #247   (Valid Article)
#  - Loadind Article #248   (Valid Article)
#  - Loadind Article #249   (Valid Article)
#  - Loadind Article #250   (Valid Article)
#  - Loadind Article #251   (Valid Article)
#  - Loadind Article #252   (Valid Article)
#  - Loadind Article #253   (Valid Article)
#  - Loadind Article #254   (Valid Article)
#  - Loadind Article #255   (Valid Article)
#  - Loadind Article #256   (Valid Article)
#  - Loadind Article #257   (Valid Article)
#  - Loadind Article #258   (Valid Article)
#  - Loadind Article #259   (Valid Article)
#  - Loadind Article #260   (Valid Article)
#  - Loadind Article #261   (Valid Article)
#  - Loadind Article #262   (Valid Article)
#  - Loadind Article #263   (Not valid : Dict could not be read)
#  - Loadind Article #264   (Valid Article)
#  - Loadind Article #265   (Valid Article)
#  - Loadind Article #266   (Valid Article)
#  - Loadind Article #267   (Valid Article)
#  - Loadind Article #268   (Valid Article)
#  - Loadind Article #269   (Valid Article)
#  - Loadind Article #270   (Valid Article)
#  - Loadind Article #271   (Valid Article)
#  - Loadind Article #272   (Valid Article)
#  - Loadind Article #273   (Valid Article)
#  - Loadind Article #274   (Valid Article)
#  - Loadind Article #275   (Valid Article)
#  - Loadind Article #276   (Valid Article)
#  - Loadind Article #277   (Valid Article)
#  - Loadind Article #278   (Not valid : Dict could not be read)
#  - Loadind Article #279   (Not valid : Dict could not be read)
#  - Loadind Article #280   (Valid Article)
#  - Loadind Article #281   (Valid Article)
#  - Loadind Article #282   (Valid Article)
#  - Loadind Article #283   (Valid Article)
#  - Loadind Article #284   (Valid Article)
#  - Loadind Article #285   (Valid Article)
#  - Loadind Article #286   (Not valid : Dict could not be read)
#  - Loadind Article #287   (Not valid : Text empty)
#  - Loadind Article #288   (Valid Article)
#  - Loadind Article #289   (Valid Article)
#  - Loadind Article #290   (Valid Article)
#  - Loadind Article #291   (Valid Article)
#  - Loadind Article #292   (Valid Article)
#  - Loadind Article #293   (Valid Article)
#  - Loadind Article #294   (Valid Article)
#  - Loadind Article #295   (Valid Article)
#  - Loadind Article #296   (Valid Article)
#  - Loadind Article #297   (Valid Article)
#  - Loadind Article #298   (Valid Article)
#  - Loadind Article #299   (Valid Article)
#  - Loadind Article #300   (Valid Article)
#  - Loadind Article #301   (Valid Article)
#  - Loadind Article #302   (Valid Article)
#  - Loadind Article #303   (Valid Article)
#  - Loadind Article #304   (Valid Article)
#  - Loadind Article #305   (Valid Article)
#  - Loadind Article #306   (Valid Article)
#  - Loadind Article #307   (Valid Article)
#  - Loadind Article #308   (Valid Article)
#  - Loadind Article #309   (Valid Article)
#  - Loadind Article #310   (Valid Article)
#  - Loadind Article #311   (Not valid : Dict could not be read)
#  - Loadind Article #312   (Valid Article)
#  - Loadind Article #313   (Valid Article)
#  - Loadind Article #314   (Valid Article)
#  - Loadind Article #315   (Valid Article)
#  - Loadind Article #316   (Not valid : Dict could not be read)
#  - Loadind Article #317   (Valid Article)
#  - Loadind Article #318   (Valid Article)
#  - Loadind Article #319   (Valid Article)
#  - Loadind Article #320   (Valid Article)
#  - Loadind Article #321   (Valid Article)
#  - Loadind Article #322   (Valid Article)
#  - Loadind Article #323   (Valid Article)
#  - Loadind Article #324   (Valid Article)
#  - Loadind Article #325   (Valid Article)
#  - Loadind Article #326   (Valid Article)
#  - Loadind Article #327   (Valid Article)
#  - Loadind Article #328   (Valid Article)
#  - Loadind Article #329   (Valid Article)
#  - Loadind Article #330   (Not valid : Dict could not be read)
#  - Loadind Article #331   (Valid Article)
#  - Loadind Article #332   (Valid Article)
#  - Loadind Article #333   (Valid Article)
#  - Loadind Article #334   (Valid Article)
#  - Loadind Article #335   (Valid Article)
#  - Loadind Article #336   (Valid Article)
#  - Loadind Article #337   (Valid Article)
#  - Loadind Article #338   (Valid Article)
#  - Loadind Article #339   (Not valid : Dict could not be read)
#  - Loadind Article #340   (Valid Article)
#  - Loadind Article #341   (Valid Article)
#  - Loadind Article #342   (Valid Article)
#  - Loadind Article #343   (Valid Article)
#  - Loadind Article #344   (Not valid : Dict could not be read)
#  - Loadind Article #345   (Valid Article)
#  - Loadind Article #346   (Valid Article)
#  - Loadind Article #347   (Valid Article)
#  - Loadind Article #348   (Valid Article)
#  - Loadind Article #349   (Valid Article)
#  - Loadind Article #350   (Not valid : Text empty)
#  - Loadind Article #351   (Valid Article)
#  - Loadind Article #352   (Valid Article)
#  - Loadind Article #353   (Valid Article)
#  - Loadind Article #354   (Valid Article)
#  - Loadind Article #355   (Valid Article)
#  - Loadind Article #356   (Valid Article)
#  - Loadind Article #357   (Valid Article)
#  - Loadind Article #358   (Valid Article)
#  - Loadind Article #359   (Valid Article)
#  - Loadind Article #360   (Valid Article)
#  - Loadind Article #361   (Not valid : Dict could not be read)
#  - Loadind Article #362   (Valid Article)
#  - Loadind Article #363   (Valid Article)
#  - Loadind Article #364   (Valid Article)
#  - Loadind Article #365   (Valid Article)
#  - Loadind Article #366   (Valid Article)
#  - Loadind Article #367   (Valid Article)
#  - Loadind Article #368   (Valid Article)
#  - Loadind Article #369   (Valid Article)
#  - Loadind Article #370   (Valid Article)
#  - Loadind Article #371   (Valid Article)
#  - Loadind Article #372   (Valid Article)
#  - Loadind Article #373   (Valid Article)
#  - Loadind Article #374   (Valid Article)
#  - Loadind Article #375   (Valid Article)
#  - Loadind Article #376   (Valid Article)
#  - Loadind Article #377   (Valid Article)
#  - Loadind Article #378   (Valid Article)
#  - Loadind Article #379   (Valid Article)
#  - Loadind Article #380   (Valid Article)
#  - Loadind Article #381   (Valid Article)
#  - Loadind Article #382   (Not valid : Dict could not be read)
#  - Loadind Article #383   (Valid Article)
#  - Loadind Article #384   (Valid Article)
#  - Loadind Article #385   (Valid Article)
#  - Loadind Article #386   (Valid Article)
#  - Loadind Article #387   (Valid Article)
#  - Loadind Article #388   (Valid Article)
#  - Loadind Article #389   (Valid Article)
#  - Loadind Article #390   (Valid Article)
#  - Loadind Article #391   (Valid Article)
#  - Loadind Article #392   (Not valid : Dict could not be read)
#  - Loadind Article #393   (Valid Article)
#  - Loadind Article #394   (Valid Article)
#  - Loadind Article #395   (Valid Article)
#  - Loadind Article #396   (Valid Article)
#  - Loadind Article #397   (Valid Article)
#  - Loadind Article #398   (Valid Article)
#  - Loadind Article #399   (Valid Article)
#  - Loadind Article #400   (Valid Article)
#  - Loadind Article #401   (Valid Article)
#  - Loadind Article #402   (Valid Article)
#  - Loadind Article #403   (Valid Article)
#  - Loadind Article #404   (Valid Article)
#  - Loadind Article #405   (Valid Article)
#  - Loadind Article #406   (Valid Article)
#  - Loadind Article #407   (Valid Article)
#  - Loadind Article #408   (Valid Article)
#  - Loadind Article #409   (Valid Article)
#  - Loadind Article #410   (Valid Article)
#  - Loadind Article #411   (Valid Article)
#  - Loadind Article #412   (Valid Article)
#  - Loadind Article #413   (Valid Article)
#  - Loadind Article #414   (Valid Article)
#  - Loadind Article #415   (Valid Article)
#  - Loadind Article #416   (Valid Article)
#  - Loadind Article #417   (Valid Article)
#  - Loadind Article #418   (Valid Article)
#  - Loadind Article #419   (Valid Article)
#  - Loadind Article #420   (Valid Article)
#  - Loadind Article #421   (Not valid : Dict could not be read)
#  - Loadind Article #422   (Valid Article)
#  - Loadind Article #423   (Valid Article)
#  - Loadind Article #424   (Valid Article)
#  - Loadind Article #425   (Valid Article)
#  - Loadind Article #426   (Valid Article)
#  - Loadind Article #427   (Not valid : Dict could not be read)
#  - Loadind Article #428   (Valid Article)
#  - Loadind Article #429   (Valid Article)
#  - Loadind Article #430   (Valid Article)
#  - Loadind Article #431   (Not valid : Dict could not be read)
#  - Loadind Article #432   (Valid Article)
#  - Loadind Article #433   (Valid Article)
#  - Loadind Article #434   (Valid Article)
#  - Loadind Article #435   (Not valid : Text empty)
#  - Loadind Article #436   (Valid Article)
#  - Loadind Article #437   (Valid Article)
#  - Loadind Article #438   (Valid Article)
#  - Loadind Article #439   (Valid Article)
#  - Loadind Article #440   (Valid Article)
#  - Loadind Article #441   (Valid Article)
#  - Loadind Article #442   (Valid Article)
#  - Loadind Article #443   (Valid Article)
#  - Loadind Article #444   (Valid Article)
#  - Loadind Article #445   (Valid Article)
#  - Loadind Article #446   (Valid Article)
#  - Loadind Article #447   (Not valid : Dict could not be read)
#  - Loadind Article #448   (Valid Article)
#  - Loadind Article #449   (Valid Article)
#  - Loadind Article #450   (Valid Article)
#  - Loadind Article #451   (Valid Article)
#  - Loadind Article #452   (Valid Article)
#  - Loadind Article #453   (Valid Article)
#  - Loadind Article #454   (Valid Article)
#  - Loadind Article #455   (Valid Article)
#  - Loadind Article #456   (Valid Article)
#  - Loadind Article #457   (Valid Article)
#  - Loadind Article #458   (Valid Article)
#  - Loadind Article #459   (Valid Article)
#  - Loadind Article #460   (Valid Article)
#  - Loadind Article #461   (Valid Article)
#  - Loadind Article #462   (Valid Article)
#  - Loadind Article #463   (Valid Article)
#  - Loadind Article #464   (Valid Article)
#  - Loadind Article #465   (Valid Article)
#  - Loadind Article #466   (Valid Article)
#  - Loadind Article #467   (Valid Article)
#  - Loadind Article #468   (Valid Article)
#  - Loadind Article #469   (Valid Article)
#  - Loadind Article #470   (Valid Article)
#  - Loadind Article #471   (Valid Article)
#  - Loadind Article #472   (Valid Article)
#  - Loadind Article #473   (Not valid : Dict could not be read)
#  - Loadind Article #474   (Valid Article)
#  - Loadind Article #475   (Not valid : Text empty)
#  - Loadind Article #476   (Valid Article)
#  - Loadind Article #477   (Not valid : Dict could not be read)
#  - Loadind Article #478   (Not valid : Dict could not be read)
#  - Loadind Article #479   (Valid Article)
#  - Loadind Article #480   (Valid Article)
#  - Loadind Article #481   (Valid Article)
#  - Loadind Article #482   (Valid Article)
#  - Loadind Article #483   (Valid Article)
#  - Loadind Article #484   (Valid Article)
#  - Loadind Article #485   (Valid Article)
#  - Loadind Article #486   (Valid Article)
#  - Loadind Article #487   (Valid Article)
#  - Loadind Article #488   (Valid Article)
#  - Loadind Article #489   (Valid Article)
#  - Loadind Article #490   (Valid Article)
#  - Loadind Article #491   (Valid Article)
#  - Loadind Article #492   (Valid Article)
#  - Loadind Article #493   (Valid Article)
#  - Loadind Article #494   (Valid Article)
#  - Loadind Article #495   (Valid Article)
#  - Loadind Article #496   (Valid Article)
#  - Loadind Article #497   (Valid Article)
#  - Loadind Article #498   (Valid Article)
#  - Loadind Article #499   (Valid Article)
#  - Loadind Article #500   (Valid Article)
#  - Loadind Article #501   (Valid Article)
#  - Loadind Article #502   (Valid Article)
#  - Loadind Article #503   (Not valid : Dict could not be read)
#  - Loadind Article #504   (Valid Article)
#  - Loadind Article #505   (Valid Article)
#  - Loadind Article #506   (Valid Article)
#  - Loadind Article #507   (Valid Article)
#  - Loadind Article #508   (Not valid : Dict could not be read)
#  - Loadind Article #509   (Valid Article)
#  - Loadind Article #510   (Valid Article)
#  - Loadind Article #511   (Valid Article)
#  - Loadind Article #512   (Valid Article)
#  - Loadind Article #513   (Valid Article)
#  - Loadind Article #514   (Valid Article)
#  - Loadind Article #515   (Valid Article)
#  - Loadind Article #516   (Valid Article)
#  - Loadind Article #517   (Valid Article)
#  - Loadind Article #518   (Valid Article)
#  - Loadind Article #519   (Valid Article)
#  - Loadind Article #520   (Valid Article)
#  - Loadind Article #521   (Valid Article)
#  - Loadind Article #522   (Valid Article)
#  - Loadind Article #523   (Not valid : Dict could not be read)
#  - Loadind Article #524   (Valid Article)
#  - Loadind Article #525   (Valid Article)
#  - Loadind Article #526   (Valid Article)
#  - Loadind Article #527   (Not valid : Dict could not be read)
#  - Loadind Article #528   (Valid Article)
#  - Loadind Article #529   (Valid Article)
#  - Loadind Article #530   (Valid Article)
#  - Loadind Article #531   (Not valid : Text empty)
#  - Loadind Article #532   (Valid Article)
#  - Loadind Article #533   (Valid Article)
#  - Loadind Article #534   (Valid Article)
#  - Loadind Article #535   (Valid Article)
#  - Loadind Article #536   (Valid Article)
#  - Loadind Article #537   (Valid Article)
#  - Loadind Article #538   (Valid Article)
#  - Loadind Article #539   (Valid Article)
#  - Loadind Article #540   (Valid Article)
#  - Loadind Article #541   (Valid Article)
#  - Loadind Article #542   (Valid Article)
#  - Loadind Article #543   (Valid Article)
#  - Loadind Article #544   (Valid Article)
#  - Loadind Article #545   (Valid Article)
#  - Loadind Article #546   (Valid Article)
#  - Loadind Article #547   (Valid Article)
#  - Loadind Article #548   (Valid Article)
#  - Loadind Article #549   (Valid Article)
#  - Loadind Article #550   (Valid Article)
#  - Loadind Article #551   (Valid Article)
#  - Loadind Article #552   (Valid Article)
#  - Loadind Article #553   (Not valid : Text empty)
#  - Loadind Article #554   (Valid Article)
#  - Loadind Article #555   (Not valid : Dict could not be read)
#  - Loadind Article #556   (Valid Article)
#  - Loadind Article #557   (Not valid : Dict could not be read)
#  - Loadind Article #558   (Not valid : Text empty)
#  - Loadind Article #559   (Valid Article)
#  - Loadind Article #560   (Valid Article)
#  - Loadind Article #561   (Not valid : Text empty)
#  - Loadind Article #562   (Valid Article)
#  - Loadind Article #563   (Valid Article)
#  - Loadind Article #564   (Valid Article)
#  - Loadind Article #565   (Not valid : Text empty)
#  - Loadind Article #566   (Not valid : Text empty)
#  - Loadind Article #567   (Valid Article)
#  - Loadind Article #568   (Valid Article)
#  - Loadind Article #569   (Valid Article)
#  - Loadind Article #570   (Valid Article)
#  - Loadind Article #571   (Valid Article)
#  - Loadind Article #572   (Valid Article)
#  - Loadind Article #573   (Valid Article)
#  - Loadind Article #574   (Valid Article)
#  - Loadind Article #575   (Valid Article)
#  - Loadind Article #576   (Valid Article)
#  - Loadind Article #577   (Valid Article)
#  - Loadind Article #578   (Valid Article)
#  - Loadind Article #579   (Valid Article)
#  - Loadind Article #580   (Valid Article)
#  - Loadind Article #581   (Valid Article)
#  - Loadind Article #582   (Valid Article)
#  - Loadind Article #583   (Valid Article)
#  - Loadind Article #584   (Valid Article)
#  - Loadind Article #585   (Valid Article)
#  - Loadind Article #586   (Valid Article)
#  - Loadind Article #587   (Valid Article)
#  - Loadind Article #588   (Valid Article)
#  - Loadind Article #589   (Valid Article)
#  - Loadind Article #590   (Valid Article)
#  - Loadind Article #591   (Valid Article)
#  - Loadind Article #592   (Valid Article)
#  - Loadind Article #593   (Valid Article)
#  - Loadind Article #594   (Valid Article)
#  - Loadind Article #595   (Valid Article)
#  - Loadind Article #596   (Valid Article)
#  - Loadind Article #597   (Valid Article)
#  - Loadind Article #598   (Valid Article)
#  - Loadind Article #599   (Valid Article)
#  - Loadind Article #600   (Valid Article)
#  - Loadind Article #601   (Valid Article)
#  - Loadind Article #602   (Valid Article)
#  - Loadind Article #603   (Valid Article)
#  - Loadind Article #604   (Valid Article)
#  - Loadind Article #605   (Valid Article)
#  - Loadind Article #606   (Valid Article)
#  - Loadind Article #607   (Valid Article)
#  - Loadind Article #608   (Valid Article)
#  - Loadind Article #609   (Valid Article)
#  - Loadind Article #610   (Valid Article)
#  - Loadind Article #611   (Valid Article)
#  - Loadind Article #612   (Valid Article)
#  - Loadind Article #613   (Valid Article)
#  - Loadind Article #614   (Valid Article)
#  - Loadind Article #615   (Valid Article)
#  - Loadind Article #616   (Valid Article)
#  - Loadind Article #617   (Valid Article)
#  - Loadind Article #618   (Valid Article)
#  - Loadind Article #619   (Not valid : Dict could not be read)
#  - Loadind Article #620   (Valid Article)
#  - Loadind Article #621   (Valid Article)
#  - Loadind Article #622   (Valid Article)
#  - Loadind Article #623   (Valid Article)
#  - Loadind Article #624   (Valid Article)
#  - Loadind Article #625   (Valid Article)
#  - Loadind Article #626   (Valid Article)
#  - Loadind Article #627   (Valid Article)
#  - Loadind Article #628   (Valid Article)
#  - Loadind Article #629   (Valid Article)
#  - Loadind Article #630   (Valid Article)
#  - Loadind Article #631   (Valid Article)
#  - Loadind Article #632   (Valid Article)
#  - Loadind Article #633   (Valid Article)
#  - Loadind Article #634   (Valid Article)
#  - Loadind Article #635   (Valid Article)
#  - Loadind Article #636   (Valid Article)
#  - Loadind Article #637   (Valid Article)
#  - Loadind Article #638   (Valid Article)
#  - Loadind Article #639   (Valid Article)
#  - Loadind Article #640   (Valid Article)
#  - Loadind Article #641   (Valid Article)
#  - Loadind Article #642   (Valid Article)
#  - Loadind Article #643   (Valid Article)
#  - Loadind Article #644   (Valid Article)
#  - Loadind Article #645   (Valid Article)
#  - Loadind Article #646   (Valid Article)
#  - Loadind Article #647   (Valid Article)
#  - Loadind Article #648   (Valid Article)
#  - Loadind Article #649   (Valid Article)
#  - Loadind Article #650   (Valid Article)
#  - Loadind Article #651   (Not valid : Dict could not be read)
#  - Loadind Article #652   (Not valid : Dict could not be read)
#  - Loadind Article #653   (Valid Article)
#  - Loadind Article #654   (Valid Article)
#  - Loadind Article #655   (Valid Article)
#  - Loadind Article #656   (Not valid : Dict could not be read)
#  - Loadind Article #657   (Valid Article)
#  - Loadind Article #658   (Valid Article)
#  - Loadind Article #659   (Not valid : Dict could not be read)
#  - Loadind Article #660   (Not valid : Dict could not be read)
#  - Loadind Article #661   (Valid Article)
#  - Loadind Article #662   (Valid Article)
#  - Loadind Article #663   (Valid Article)
#  - Loadind Article #664   (Valid Article)
#  - Loadind Article #665   (Valid Article)
#  - Loadind Article #666   (Not valid : Dict could not be read)
#  - Loadind Article #667   (Valid Article)
#  - Loadind Article #668   (Valid Article)
#  - Loadind Article #669   (Valid Article)
#  - Loadind Article #670   (Valid Article)
#  - Loadind Article #671   (Valid Article)
#  - Loadind Article #672   (Valid Article)
#  - Loadind Article #673   (Valid Article)
#  - Loadind Article #674   (Valid Article)
#  - Loadind Article #675   (Valid Article)
#  - Loadind Article #676   (Valid Article)
#  - Loadind Article #677   (Valid Article)
#  - Loadind Article #678   (Valid Article)
#  - Loadind Article #679   (Valid Article)
#  - Loadind Article #680   (Valid Article)
#  - Loadind Article #681   (Valid Article)
#  - Loadind Article #682   (Valid Article)
#  - Loadind Article #683   (Valid Article)
#  - Loadind Article #684   (Valid Article)
#  - Loadind Article #685   (Not valid : Dict could not be read)
#  - Loadind Article #686   (Valid Article)
#  - Loadind Article #687   (Valid Article)
#  - Loadind Article #688   (Not valid : Text empty)
#  - Loadind Article #689   (Valid Article)
#  - Loadind Article #690   (Valid Article)
#  - Loadind Article #691   (Valid Article)
#  - Loadind Article #692   (Valid Article)
#  - Loadind Article #693   (Valid Article)
#  - Loadind Article #694   (Not valid : Dict could not be read)
#  - Loadind Article #695   (Valid Article)
#  - Loadind Article #696   (Valid Article)
#  - Loadind Article #697   (Valid Article)
#  - Loadind Article #698   (Valid Article)
#  - Loadind Article #699   (Valid Article)
#  - Loadind Article #700   (Valid Article)
#  - Loadind Article #701   (Valid Article)
#  - Loadind Article #702   (Valid Article)
#  - Loadind Article #703   (Valid Article)
#  - Loadind Article #704   (Valid Article)
#  - Loadind Article #705   (Valid Article)
#  - Loadind Article #706   (Valid Article)
#  - Loadind Article #707   (Valid Article)
#  - Loadind Article #708   (Valid Article)
#  - Loadind Article #709   (Valid Article)
#  - Loadind Article #710   (Valid Article)
#  - Loadind Article #711   (Valid Article)
#  - Loadind Article #712   (Not valid : Dict could not be read)
#  - Loadind Article #713   (Valid Article)
#  - Loadind Article #714   (Valid Article)
#  - Loadind Article #715   (Valid Article)
#  - Loadind Article #716   (Valid Article)
#  - Loadind Article #717   (Not valid : Dict could not be read)
#  - Loadind Article #718   (Valid Article)
#  - Loadind Article #719   (Valid Article)
#  - Loadind Article #720   (Not valid : Dict could not be read)
#  - Loadind Article #721   (Valid Article)
#  - Loadind Article #722   (Valid Article)
#  - Loadind Article #723   (Valid Article)
#  - Loadind Article #724   (Valid Article)
#  - Loadind Article #725   (Valid Article)
#  - Loadind Article #726   (Not valid : Dict could not be read)
#  - Loadind Article #727   (Valid Article)
#  - Loadind Article #728   (Valid Article)
#  - Loadind Article #729   (Not valid : Dict could not be read)
#  - Loadind Article #730   (Valid Article)
#  - Loadind Article #731   (Not valid : Text empty)
#  - Loadind Article #732   (Valid Article)
#  - Loadind Article #733   (Valid Article)
#  - Loadind Article #734   (Valid Article)
#  - Loadind Article #735   (Valid Article)
#  - Loadind Article #736   (Valid Article)
#  - Loadind Article #737   (Valid Article)
#  - Loadind Article #738   (Valid Article)
#  - Loadind Article #739   (Valid Article)
#  - Loadind Article #740   (Valid Article)
#  - Loadind Article #741   (Valid Article)
#  - Loadind Article #742   (Not valid : Dict could not be read)
#  - Loadind Article #743   (Valid Article)
#  - Loadind Article #744   (Valid Article)
#  - Loadind Article #745   (Not valid : Dict could not be read)
#  - Loadind Article #746   (Valid Article)
#  - Loadind Article #747   (Valid Article)
#  - Loadind Article #748   (Valid Article)
#  - Loadind Article #749   (Valid Article)
#  - Loadind Article #750   (Valid Article)
#  - Loadind Article #751   (Valid Article)
#  - Loadind Article #752   (Valid Article)
#  - Loadind Article #753   (Valid Article)
#  - Loadind Article #754   (Valid Article)
#  - Loadind Article #755   (Valid Article)
#  - Loadind Article #756   (Valid Article)
#  - Loadind Article #757   (Valid Article)
#  - Loadind Article #758   (Valid Article)
#  - Loadind Article #759   (Valid Article)
#  - Loadind Article #760   (Not valid : Text empty)
#  - Loadind Article #761   (Valid Article)
#  - Loadind Article #762   (Valid Article)
#  - Loadind Article #763   (Valid Article)
#  - Loadind Article #764   (Valid Article)
#  - Loadind Article #765   (Not valid : Text empty)
#  - Loadind Article #766   (Valid Article)
#  - Loadind Article #767   (Valid Article)
#  - Loadind Article #768   (Valid Article)
#  - Loadind Article #769   (Valid Article)
#  - Loadind Article #770   (Valid Article)
#  - Loadind Article #771   (Not valid : Dict could not be read)
#  - Loadind Article #772   (Not valid : Dict could not be read)
#  - Loadind Article #773   (Valid Article)
#  - Loadind Article #774   (Valid Article)
#  - Loadind Article #775   (Valid Article)
#  - Loadind Article #776   (Valid Article)
#  - Loadind Article #777   (Valid Article)
#  - Loadind Article #778   (Valid Article)
#  - Loadind Article #779   (Valid Article)
#  - Loadind Article #780   (Not valid : Dict could not be read)
#  - Loadind Article #781   (Valid Article)
#  - Loadind Article #782   (Valid Article)
#  - Loadind Article #783   (Valid Article)
#  - Loadind Article #784   (Valid Article)
#  - Loadind Article #785   (Valid Article)
#  - Loadind Article #786   (Valid Article)
#  - Loadind Article #787   (Not valid : Dict could not be read)
#  - Loadind Article #788   (Valid Article)
#  - Loadind Article #789   (Valid Article)
#  - Loadind Article #790   (Valid Article)
#  - Loadind Article #791   (Valid Article)
#  - Loadind Article #792   (Valid Article)
#  - Loadind Article #793   (Not valid : Dict could not be read)
#  - Loadind Article #794   (Valid Article)
#  - Loadind Article #795   (Valid Article)
#  - Loadind Article #796   (Valid Article)
#  - Loadind Article #797   (Valid Article)
#  - Loadind Article #798   (Valid Article)
#  - Loadind Article #799   (Valid Article)
#  - Loadind Article #800   (Valid Article)
#  - Loadind Article #801   (Valid Article)
#  - Loadind Article #802   (Valid Article)
#  - Loadind Article #803   (Valid Article)
#  - Loadind Article #804   (Not valid : Dict could not be read)
#  - Loadind Article #805   (Valid Article)
#  - Loadind Article #806   (Valid Article)
#  - Loadind Article #807   (Valid Article)
#  - Loadind Article #808   (Valid Article)
#  - Loadind Article #809   (Valid Article)
#  - Loadind Article #810   (Valid Article)
#  - Loadind Article #811   (Valid Article)
#  - Loadind Article #812   (Valid Article)
#  - Loadind Article #813   (Valid Article)
#  - Loadind Article #814   (Valid Article)
#  - Loadind Article #815   (Valid Article)
#  - Loadind Article #816   (Valid Article)
#  - Loadind Article #817   (Not valid : Text empty)
#  - Loadind Article #818   (Valid Article)
#  - Loadind Article #819   (Valid Article)
#  - Loadind Article #820   (Valid Article)
#  - Loadind Article #821   (Valid Article)
#  - Loadind Article #822   (Valid Article)
#  - Loadind Article #823   (Not valid : Dict could not be read)
#  - Loadind Article #824   (Valid Article)
#  - Loadind Article #825   (Valid Article)
#  - Loadind Article #826   (Not valid : Dict could not be read)
#  - Loadind Article #827   (Valid Article)
#  - Loadind Article #828   (Valid Article)
#  - Loadind Article #829   (Valid Article)
#  - Loadind Article #830   (Not valid : Dict could not be read)
#  - Loadind Article #831   (Valid Article)
#  - Loadind Article #832   (Valid Article)
#  - Loadind Article #833   (Valid Article)
#  - Loadind Article #834   (Valid Article)
#  - Loadind Article #835   (Valid Article)
#  - Loadind Article #836   (Not valid : Dict could not be read)
#  - Loadind Article #837   (Valid Article)
#  - Loadind Article #838   (Valid Article)
#  - Loadind Article #839   (Not valid : Text empty)
#  - Loadind Article #840   (Valid Article)
#  - Loadind Article #841   (Valid Article)
#  - Loadind Article #842   (Not valid : Dict could not be read)
#  - Loadind Article #843   (Valid Article)
#  - Loadind Article #844   (Valid Article)
#  - Loadind Article #845   (Valid Article)
#  - Loadind Article #846   (Valid Article)
#  - Loadind Article #847   (Valid Article)
#  - Loadind Article #848   (Valid Article)
#  - Loadind Article #849   (Not valid : Text empty)
#  - Loadind Article #850   (Valid Article)
#  - Loadind Article #851   (Valid Article)
#  - Loadind Article #852   (Valid Article)
#  - Loadind Article #853   (Valid Article)
#  - Loadind Article #854   (Valid Article)
#  - Loadind Article #855   (Valid Article)
#  - Loadind Article #856   (Valid Article)
#  - Loadind Article #857   (Valid Article)
#  - Loadind Article #858   (Valid Article)
#  - Loadind Article #859   (Valid Article)
#  - Loadind Article #860   (Valid Article)
#  - Loadind Article #861   (Valid Article)
#  - Loadind Article #862   (Valid Article)
#  - Loadind Article #863   (Valid Article)
#  - Loadind Article #864   (Valid Article)
#  - Loadind Article #865   (Valid Article)
#  - Loadind Article #866   (Valid Article)
#  - Loadind Article #867   (Valid Article)
#  - Loadind Article #868   (Valid Article)
#  - Loadind Article #869   (Valid Article)
#  - Loadind Article #870   (Valid Article)
#  - Loadind Article #871   (Not valid : Dict could not be read)
#  - Loadind Article #872   (Valid Article)
#  - Loadind Article #873   (Valid Article)
#  - Loadind Article #874   (Valid Article)
#  - Loadind Article #875   (Valid Article)
#  - Loadind Article #876   (Valid Article)
#  - Loadind Article #877   (Valid Article)
#  - Loadind Article #878   (Valid Article)
#  - Loadind Article #879   (Valid Article)
#  - Loadind Article #880   (Valid Article)
#  - Loadind Article #881   (Valid Article)
#  - Loadind Article #882   (Valid Article)
#  - Loadind Article #883   (Valid Article)
#  - Loadind Article #884   (Valid Article)
#  - Loadind Article #885   (Valid Article)
#  - Loadind Article #886   (Valid Article)
#  - Loadind Article #887   (Valid Article)
#  - Loadind Article #888   (Valid Article)
#  - Loadind Article #889   (Valid Article)
#  - Loadind Article #890   (Valid Article)
#  - Loadind Article #891   (Valid Article)
#  - Loadind Article #892   (Valid Article)
#  - Loadind Article #893   (Valid Article)
#  - Loadind Article #894   (Valid Article)
#  - Loadind Article #895   (Valid Article)
#  - Loadind Article #896   (Valid Article)
#  - Loadind Article #897   (Valid Article)
#  - Loadind Article #898   (Valid Article)
#  - Loadind Article #899   (Valid Article)
#  - Loadind Article #900   (Valid Article)
#  - Loadind Article #901   (Valid Article)
#  - Loadind Article #902   (Valid Article)
#  - Loadind Article #903   (Valid Article)
#  - Loadind Article #904   (Valid Article)
#  - Loadind Article #905   (Valid Article)
#  - Loadind Article #906   (Not valid : Text empty)
#  - Loadind Article #907   (Valid Article)
#  - Loadind Article #908   (Valid Article)
#  - Loadind Article #909   (Valid Article)
#  - Loadind Article #910   (Valid Article)
#  - Loadind Article #911   (Valid Article)
#  - Loadind Article #912   (Not valid : Dict could not be read)
#  - Loadind Article #913   (Valid Article)
#  - Loadind Article #914   (Valid Article)
#  - Loadind Article #915   (Valid Article)
#  - Loadind Article #916   (Valid Article)
#  - Loadind Article #917   (Not valid : Text empty)
#  - Loadind Article #918   (Valid Article)
#  - Loadind Article #919   (Valid Article)
#  - Loadind Article #920   (Not valid : Text empty)
#  - Loadind Article #921   (Valid Article)
#  - Loadind Article #922   (Not valid : Text empty)
#  - Loadind Article #923   (Not valid : Text empty)
#  - Loadind Article #924   (Valid Article)
#  - Loadind Article #925   (Not valid : Text empty)
#  - Loadind Article #926   (Not valid : Text empty)
#  - Loadind Article #927   (Not valid : Text empty)
#  - Loadind Article #928   (Not valid : Text empty)
#  - Loadind Article #929   (Not valid : Text empty)
#  - Loadind Article #930   (Not valid : Text empty)
#  - Loadind Article #931   (Not valid : Text empty)
#  - Loadind Article #932   (Not valid : Text empty)
#  - Loadind Article #933   (Not valid : Text empty)
#  - Loadind Article #934   (Not valid : Text empty)
#  - Loadind Article #935   (Valid Article)
#  - Loadind Article #936   (Valid Article)
#  - Loadind Article #937   (Valid Article)
#  - Loadind Article #938   (Not valid : Text empty)
#  - Loadind Article #939   (Not valid : Text empty)
#  - Loadind Article #940   (Not valid : Text empty)
#  - Loadind Article #941   (Valid Article)
#  - Loadind Article #942   (Valid Article)
#  - Loadind Article #943   (Valid Article)
#  - Loadind Article #944   (Valid Article)
#  - Loadind Article #945   (Valid Article)
#  - Loadind Article #946   (Valid Article)
#  - Loadind Article #947   (Valid Article)
#  - Loadind Article #948   (Valid Article)
#  - Loadind Article #949   (Valid Article)
#  - Loadind Article #950   (Valid Article)
#  - Loadind Article #951   (Valid Article)
#  - Loadind Article #952   (Valid Article)
#  - Loadind Article #953   (Valid Article)
#  - Loadind Article #954   (Valid Article)
#  - Loadind Article #955   (Valid Article)
#  - Loadind Article #956   (Valid Article)
#  - Loadind Article #957   (Valid Article)
#  - Loadind Article #958   (Valid Article)
#  - Loadind Article #959   (Valid Article)
#  - Loadind Article #960   (Valid Article)
#  - Loadind Article #961   (Valid Article)
#  - Loadind Article #962   (Valid Article)
#  - Loadind Article #963   (Valid Article)
#  - Loadind Article #964   (Valid Article)
#  - Loadind Article #965   (Valid Article)
#  - Loadind Article #966   (Valid Article)
#  - Loadind Article #967   (Valid Article)
#  - Loadind Article #968   (Valid Article)
#  - Loadind Article #969   (Valid Article)
#  - Loadind Article #970   (Valid Article)
#  - Loadind Article #971   (Valid Article)
#  - Loadind Article #972   (Valid Article)
#  - Loadind Article #973   (Valid Article)
#  - Loadind Article #974   (Valid Article)
#  - Loadind Article #975   (Valid Article)
#  - Loadind Article #976   (Valid Article)
#  - Loadind Article #977   (Valid Article)
#  - Loadind Article #978   (Valid Article)
#  - Loadind Article #979   (Valid Article)
#  - Loadind Article #980   (Valid Article)
#  - Loadind Article #981   (Valid Article)
#  - Loadind Article #982   (Valid Article)
#  - Loadind Article #983   (Valid Article)
#  - Loadind Article #984   (Valid Article)
#  - Loadind Article #985   (Valid Article)
#  - Loadind Article #986   (Not valid : Dict could not be read)
#  - Loadind Article #987   (Valid Article)
#  - Loadind Article #988   (Valid Article)
#  - Loadind Article #989   (Valid Article)
#  - Loadind Article #990   (Valid Article)
#  - Loadind Article #991   (Valid Article)
#  - Loadind Article #992   (Valid Article)
#  - Loadind Article #993   (Valid Article)
#  - Loadind Article #994   (Valid Article)
#  - Loadind Article #995   (Valid Article)
#  - Loadind Article #996   (Valid Article)
#  - Loadind Article #997   (Valid Article)
#  - Loadind Article #998   (Valid Article)
#  - Loadind Article #999   (Valid Article)
#  - Loadind Article #1000   (Valid Article)
#  - Loadind Article #1001   (Valid Article)
#  - Loadind Article #1002   (Not valid : Text empty)
#  - Loadind Article #1003   (Valid Article)
#  - Loadind Article #1004   (Valid Article)
#  - Loadind Article #1005   (Valid Article)
#  - Loadind Article #1006   (Valid Article)
#  - Loadind Article #1007   (Not valid : Dict could not be read)
#  - Loadind Article #1008   (Not valid : Dict could not be read)
#  - Loadind Article #1009   (Valid Article)
#  - Loadind Article #1010   (Valid Article)
#  - Loadind Article #1011   (Valid Article)
#  - Loadind Article #1012   (Valid Article)
#  - Loadind Article #1013   (Valid Article)
#  - Loadind Article #1014   (Not valid : Dict could not be read)
#  - Loadind Article #1015   (Valid Article)
#  - Loadind Article #1016   (Valid Article)
#  - Loadind Article #1017   (Valid Article)
#  - Loadind Article #1018   (Valid Article)
#  - Loadind Article #1019   (Not valid : Dict could not be read)
#  - Loadind Article #1020   (Valid Article)
#  - Loadind Article #1021   (Not valid : Dict could not be read)
#  - Loadind Article #1022   (Valid Article)
#  - Loadind Article #1023   (Valid Article)
#  - Loadind Article #1024   (Valid Article)
#  - Loadind Article #1025   (Not valid : Dict could not be read)
#  - Loadind Article #1026   (Valid Article)
#  - Loadind Article #1027   (Valid Article)
#  - Loadind Article #1028   (Valid Article)
#  - Loadind Article #1029   (Valid Article)
#  - Loadind Article #1030   (Not valid : Dict could not be read)
#  - Loadind Article #1031   (Not valid : Dict could not be read)
#  - Loadind Article #1032   (Valid Article)
#  - Loadind Article #1033   (Valid Article)
#  - Loadind Article #1034   (Valid Article)
#  - Loadind Article #1035   (Not valid : Dict could not be read)
#  - Loadind Article #1036   (Valid Article)
#  - Loadind Article #1037   (Not valid : Text empty)
#  - Loadind Article #1038   (Not valid : Dict could not be read)
#  - Loadind Article #1039   (Not valid : Dict could not be read)
#  - Loadind Article #1040   (Not valid : Dict could not be read)
#  - Loadind Article #1041   (Not valid : Dict could not be read)
#  - Loadind Article #1042   (Valid Article)
#  - Loadind Article #1043   (Not valid : Text empty)
#  - Loadind Article #1044   (Not valid : Text empty)
#  - Loadind Article #1045   (Not valid : Dict could not be read)
#  - Loadind Article #1046   (Not valid : Text empty)
#  - Loadind Article #1047   (Not valid : Text empty)
#  - Loadind Article #1048   (Valid Article)
#  - Loadind Article #1049   (Valid Article)
#  - Loadind Article #1050   (Not valid : Dict could not be read)
#  - Loadind Article #1051   (Valid Article)
#  - Loadind Article #1052   (Valid Article)
#  - Loadind Article #1053   (Valid Article)
#  - Loadind Article #1054   (Valid Article)
#  - Loadind Article #1055   (Valid Article)
#  - Loadind Article #1056   (Not valid : Dict could not be read)
#  - Loadind Article #1057   (Valid Article)
#  - Loadind Article #1058   (Valid Article)
#  - Loadind Article #1059   (Valid Article)
#  - Loadind Article #1060   (Valid Article)
#  - Loadind Article #1061   (Valid Article)
#  - Loadind Article #1062   (Valid Article)
#  - Loadind Article #1063   (Valid Article)
#  - Loadind Article #1064   (Valid Article)
#  - Loadind Article #1065   (Valid Article)
#  - Loadind Article #1066   (Valid Article)
#  - Loadind Article #1067   (Valid Article)
#  - Loadind Article #1068   (Not valid : Dict could not be read)
#  - Loadind Article #1069   (Valid Article)
#  - Loadind Article #1070   (Valid Article)
#  - Loadind Article #1071   (Valid Article)
#  - Loadind Article #1072   (Valid Article)
#  - Loadind Article #1073   (Valid Article)
#  - Loadind Article #1074   (Valid Article)
#  - Loadind Article #1075   (Valid Article)
#  - Loadind Article #1076   (Valid Article)
#  - Loadind Article #1077   (Valid Article)
#  - Loadind Article #1078   (Valid Article)
#  - Loadind Article #1079   (Valid Article)
#  - Loadind Article #1080   (Valid Article)
#  - Loadind Article #1081   (Valid Article)
#  - Loadind Article #1082   (Not valid : Text empty)
#  - Loadind Article #1083   (Valid Article)
#  - Loadind Article #1084   (Valid Article)
#  - Loadind Article #1085   (Valid Article)
# ...
#  - Loadind Article #2115   (Valid Article)
#  - Loadind Article #2116   (Valid Article)
#  - Loadind Article #2117   (Valid Article)
#  - Loadind Article #2118   (Not valid : Dict could not be read)
#  - Loadind Article #2119   (Valid Article)
#  - Loadind Article #2120   (Valid Article)
#  - Loadind Article #2121   (Valid Article)
#  - Loadind Article #2122   (Not valid : Dict could not be read)
#  - Loadind Article #2123   (Not valid : Dict could not be read)
#  - Loadind Article #2124   (Valid Article)
#  - Loadind Article #2125   (Valid Article)
#  - Loadind Article #2126   (Valid Article)
#  - Loadind Article #2127   (Valid Article)
#  - Loadind Article #2128   (Valid Article)
#  - Loadind Article #2129   (Valid Article)
#  - Loadind Article #2130   (Valid Article)
#  - Loadind Article #2131   (Valid Article)
#  - Loadind Article #2132   (Valid Article)
#  - Loadind Article #2133   (Valid Article)
#  - Loadind Article #2134   (Valid Article)
#  - Loadind Article #2135   (Valid Article)
#  - Loadind Article #2136   (Valid Article)
#  - Loadind Article #2137   (Valid Article)
#  - Loadind Article #2138   (Valid Article)
#  - Loadind Article #2139   (Valid Article)
#  - Loadind Article #2140   (Valid Article)
#  - Loadind Article #2141   (Valid Article)
#  - Loadind Article #2142   (Valid Article)
#  - Loadind Article #2143   (Valid Article)
#  - Loadind Article #2144   (Valid Article)
#  - Loadind Article #2145   (Valid Article)
#  - Loadind Article #2146   (Not valid : Dict could not be read)
#  - Loadind Article #2147   (Valid Article)
#  - Loadind Article #2148   (Valid Article)
#  - Loadind Article #2149   (Valid Article)
#  - Loadind Article #2150   (Valid Article)
#  - Loadind Article #2151   (Valid Article)
#  - Loadind Article #2152   (Valid Article)
#  - Loadind Article #2153   (Valid Article)
#  - Loadind Article #2154   (Valid Article)
#  - Loadind Article #2155   (Valid Article)
#  - Loadind Article #2156   (Valid Article)
#  - Loadind Article #2157   (Not valid : Dict could not be read)
#  - Loadind Article #2158   (Valid Article)
#  - Loadind Article #2159   (Valid Article)
#  - Loadind Article #2160   (Valid Article)
#  - Loadind Article #2161   (Valid Article)
#  - Loadind Article #2162   (Valid Article)
#  - Loadind Article #2163   (Valid Article)
#  - Loadind Article #2164   (Valid Article)
#  - Loadind Article #2165   (Valid Article)
#  - Loadind Article #2166   (Valid Article)
#  - Loadind Article #2167   (Valid Article)
#  - Loadind Article #2168   (Valid Article)
#  - Loadind Article #2169   (Valid Article)
#  - Loadind Article #2170   (Valid Article)
#  - Loadind Article #2171   (Valid Article)
#  - Loadind Article #2172   (Valid Article)
#  - Loadind Article #2173   (Valid Article)
#  - Loadind Article #2174   (Valid Article)
#  - Loadind Article #2175   (Valid Article)
#  - Loadind Article #2176   (Valid Article)
#  - Loadind Article #2177   (Valid Article)
#  - Loadind Article #2178   (Not valid : Dict could not be read)
#  - Loadind Article #2179   (Valid Article)
#  - Loadind Article #2180   (Valid Article)
#  - Loadind Article #2181   (Not valid : Dict could not be read)
#  - Loadind Article #2182   (Valid Article)
#  - Loadind Article #2183   (Not valid : Dict could not be read)
#  - Loadind Article #2184   (Valid Article)
#  - Loadind Article #2185   (Not valid : Dict could not be read)
#  - Loadind Article #2186   (Not valid : Text empty)
#  - Loadind Article #2187   (Valid Article)
#  - Loadind Article #2188   (Valid Article)
#  - Loadind Article #2189   (Valid Article)
#  - Loadind Article #2190   (Valid Article)
#  - Loadind Article #2191   (Not valid : Text empty)
#  - Loadind Article #2192   (Valid Article)
#  - Loadind Article #2193   (Valid Article)
#  - Loadind Article #2194   (Valid Article)
#  - Loadind Article #2195   (Valid Article)
#  - Loadind Article #2196   (Valid Article)
#  - Loadind Article #2197   (Valid Article)
#  - Loadind Article #2198   (Not valid : Dict could not be read)
#  - Loadind Article #2199   (Valid Article)
#  - Loadind Article #2200   (Valid Article)
#  - Loadind Article #2201   (Valid Article)
#  - Loadind Article #2202   (Not valid : Text empty)
#  - Loadind Article #2203   (Not valid : Text empty)
#  - Loadind Article #2204   (Valid Article)
#  - Loadind Article #2205   (Not valid : Dict could not be read)
#  - Loadind Article #2206   (Not valid : Text empty)
#  - Loadind Article #2207   (Valid Article)
#  - Loadind Article #2208   (Valid Article)
#  - Loadind Article #2209   (Valid Article)
#  - Loadind Article #2210   (Valid Article)
#  - Loadind Article #2211   (Valid Article)
#  - Loadind Article #2212   (Valid Article)
#  - Loadind Article #2213   (Valid Article)
#  - Loadind Article #2214   (Valid Article)
#  - Loadind Article #2215   (Not valid : Dict could not be read)
#  - Loadind Article #2216   (Not valid : Text empty)
#  - Loadind Article #2217   (Valid Article)
#  - Loadind Article #2218   (Valid Article)
#  - Loadind Article #2219   (Valid Article)
#  - Loadind Article #2220   (Valid Article)
#  - Loadind Article #2221   (Valid Article)
#  - Loadind Article #2222   (Valid Article)
#  - Loadind Article #2223   (Valid Article)
#  - Loadind Article #2224   (Valid Article)
#  - Loadind Article #2225   (Valid Article)
#  - Loadind Article #2226   (Not valid : Dict could not be read)
#  - Loadind Article #2227   (Valid Article)
#  - Loadind Article #2228   (Valid Article)
#  - Loadind Article #2229   (Valid Article)
#  - Loadind Article #2230   (Valid Article)
#  - Loadind Article #2231   (Valid Article)
#  - Loadind Article #2232   (Valid Article)
#  - Loadind Article #2233   (Not valid : Dict could not be read)
#  - Loadind Article #2234   (Valid Article)
#  - Loadind Article #2235   (Not valid : Dict could not be read)
#  - Loadind Article #2236   (Valid Article)
#  - Loadind Article #2237   (Valid Article)
#  - Loadind Article #2238   (Valid Article)
#  - Loadind Article #2239   (Valid Article)
#  - Loadind Article #2240   (Valid Article)
#  - Loadind Article #2241   (Valid Article)
#  - Loadind Article #2242   (Valid Article)
#  - Loadind Article #2243   (Valid Article)
#  - Loadind Article #2244   (Valid Article)
#  - Loadind Article #2245   (Valid Article)
#  - Loadind Article #2246   (Not valid : Dict could not be read)
#  - Loadind Article #2247   (Not valid : Text empty)
#  - Loadind Article #2248   (Valid Article)
#  - Loadind Article #2249   (Valid Article)
#  - Loadind Article #2250   (Valid Article)
#  - Loadind Article #2251   (Not valid : Text empty)
#  - Loadind Article #2252   (Valid Article)
#  - Loadind Article #2253   (Valid Article)
#  - Loadind Article #2254   (Valid Article)
#  - Loadind Article #2255   (Valid Article)
#  - Loadind Article #2256   (Valid Article)
#  - Loadind Article #2257   (Valid Article)
#  - Loadind Article #2258   (Valid Article)
#  - Loadind Article #2259   (Valid Article)
#  - Loadind Article #2260   (Valid Article)
#  - Loadind Article #2261   (Valid Article)
#  - Loadind Article #2262   (Valid Article)
#  - Loadind Article #2263   (Valid Article)
#  - Loadind Article #2264   (Valid Article)
#  - Loadind Article #2265   (Valid Article)
#  - Loadind Article #2266   (Valid Article)
#  - Loadind Article #2267   (Valid Article)
#  - Loadind Article #2268   (Valid Article)
#  - Loadind Article #2269   (Valid Article)
#  - Loadind Article #2270   (Valid Article)
#  - Loadind Article #2271   (Not valid : Dict could not be read)
#  - Loadind Article #2272   (Valid Article)
#  - Loadind Article #2273   (Valid Article)
#  - Loadind Article #2274   (Valid Article)
#  - Loadind Article #2275   (Valid Article)
#  - Loadind Article #2276   (Valid Article)
#  - Loadind Article #2277   (Valid Article)
#  - Loadind Article #2278   (Valid Article)
#  - Loadind Article #2279   (Valid Article)
#  - Loadind Article #2280   (Valid Article)
#  - Loadind Article #2281   (Valid Article)
#  - Loadind Article #2282   (Valid Article)
#  - Loadind Article #2283   (Valid Article)
#  - Loadind Article #2284   (Valid Article)
#  - Loadind Article #2285   (Valid Article)
#  - Loadind Article #2286   (Valid Article)
#  - Loadind Article #2287   (Valid Article)
#  - Loadind Article #2288   (Valid Article)
#  - Loadind Article #2289   (Valid Article)
#  - Loadind Article #2290   (Valid Article)
#  - Loadind Article #2291   (Valid Article)
#  - Loadind Article #2292   (Valid Article)
#  - Loadind Article #2293   (Not valid : Dict could not be read)
#  - Loadind Article #2294   (Valid Article)
#  - Loadind Article #2295   (Valid Article)
#  - Loadind Article #2296   (Valid Article)
#  - Loadind Article #2297   (Valid Article)
#  - Loadind Article #2298   (Valid Article)
#  - Loadind Article #2299   (Valid Article)
#  - Loadind Article #2300   (Valid Article)
#  - Loadind Article #2301   (Valid Article)
#  - Loadind Article #2302   (Valid Article)
#  - Loadind Article #2303   (Valid Article)
#  - Loadind Article #2304   (Valid Article)
#  - Loadind Article #2305   (Valid Article)
#  - Loadind Article #2306   (Valid Article)
#  - Loadind Article #2307   (Not valid : Text empty)
#  - Loadind Article #2308   (Valid Article)
#  - Loadind Article #2309   (Valid Article)
#  - Loadind Article #2310   (Valid Article)
#  - Loadind Article #2311   (Valid Article)
#  - Loadind Article #2312   (Valid Article)
#  - Loadind Article #2313   (Valid Article)
#  - Loadind Article #2314   (Valid Article)
#  - Loadind Article #2315   (Valid Article)
#  - Loadind Article #2316   (Valid Article)
#  - Loadind Article #2317   (Valid Article)
#  - Loadind Article #2318   (Valid Article)
#  - Loadind Article #2319   (Valid Article)
#  - Loadind Article #2320   (Valid Article)
#  - Loadind Article #2321   (Valid Article)
#  - Loadind Article #2322   (Valid Article)
#  - Loadind Article #2323   (Not valid : Dict could not be read)
#  - Loadind Article #2324   (Valid Article)
#  - Loadind Article #2325   (Valid Article)
#  - Loadind Article #2326   (Not valid : Text empty)
#  - Loadind Article #2327   (Valid Article)
#  - Loadind Article #2328   (Valid Article)
#  - Loadind Article #2329   (Valid Article)
#  - Loadind Article #2330   (Valid Article)
#  - Loadind Article #2331   (Valid Article)
#  - Loadind Article #2332   (Valid Article)
#  - Loadind Article #2333   (Valid Article)
#  - Loadind Article #2334   (Valid Article)
#  - Loadind Article #2335   (Valid Article)
#  - Loadind Article #2336   (Valid Article)
#  - Loadind Article #2337   (Valid Article)
#  - Loadind Article #2338   (Valid Article)
#  - Loadind Article #2339   (Valid Article)
#  - Loadind Article #2340   (Valid Article)
#  - Loadind Article #2341   (Valid Article)
#  - Loadind Article #2342   (Valid Article)
#  - Loadind Article #2343   (Valid Article)
#  - Loadind Article #2344   (Valid Article)
#  - Loadind Article #2345   (Valid Article)
#  - Loadind Article #2346   (Valid Article)
#  - Loadind Article #2347   (Not valid : Dict could not be read)
#  - Loadind Article #2348   (Valid Article)
#  - Loadind Article #2349   (Valid Article)
#  - Loadind Article #2350   (Valid Article)
#  - Loadind Article #2351   (Valid Article)
#  - Loadind Article #2352   (Valid Article)
#  - Loadind Article #2353   (Valid Article)
#  - Loadind Article #2354   (Valid Article)
#  - Loadind Article #2355   (Valid Article)
#  - Loadind Article #2356   (Valid Article)
#  - Loadind Article #2357   (Valid Article)
#  - Loadind Article #2358   (Valid Article)
#  - Loadind Article #2359   (Valid Article)
#  - Loadind Article #2360   (Valid Article)
#  - Loadind Article #2361   (Valid Article)
#  - Loadind Article #2362   (Valid Article)
#  - Loadind Article #2363   (Valid Article)
#  - Loadind Article #2364   (Not valid : Text empty)
#  - Loadind Article #2365   (Valid Article)
#  - Loadind Article #2366   (Valid Article)
#  - Loadind Article #2367   (Valid Article)
#  - Loadind Article #2368   (Valid Article)
#  - Loadind Article #2369   (Valid Article)
#  - Loadind Article #2370   (Valid Article)
#  - Loadind Article #2371   (Valid Article)
#  - Loadind Article #2372   (Valid Article)
#  - Loadind Article #2373   (Valid Article)
#  - Loadind Article #2374   (Valid Article)
#  - Loadind Article #2375   (Valid Article)
#  - Loadind Article #2376   (Valid Article)
#  - Loadind Article #2377   (Valid Article)
#  - Loadind Article #2378   (Valid Article)
#  - Loadind Article #2379   (Valid Article)
#  - Loadind Article #2380   (Valid Article)
#  - Loadind Article #2381   (Valid Article)
#  - Loadind Article #2382   (Valid Article)
#  - Loadind Article #2383   (Valid Article)
#  - Loadind Article #2384   (Valid Article)
#  - Loadind Article #2385   (Valid Article)
#  - Loadind Article #2386   (Valid Article)
#  - Loadind Article #2387   (Valid Article)
#  - Loadind Article #2388   (Valid Article)
#  - Loadind Article #2389   (Valid Article)
#  - Loadind Article #2390   (Valid Article)
#  - Loadind Article #2391   (Valid Article)
#  - Loadind Article #2392   (Valid Article)
#  - Loadind Article #2393   (Valid Article)
#  - Loadind Article #2394   (Valid Article)
#  - Loadind Article #2395   (Valid Article)
#  - Loadind Article #2396   (Valid Article)
#  - Loadind Article #2397   (Valid Article)
#  - Loadind Article #2398   (Valid Article)
#  - Loadind Article #2399   (Valid Article)
#  - Loadind Article #2400   (Valid Article)
#  - Loadind Article #2401   (Valid Article)
#  - Loadind Article #2402   (Valid Article)
#  - Loadind Article #2403   (Valid Article)
#  - Loadind Article #2404   (Valid Article)
#  - Loadind Article #2405   (Valid Article)
#  - Loadind Article #2406   (Valid Article)
#  - Loadind Article #2407   (Valid Article)
#  - Loadind Article #2408   (Valid Article)
#  - Loadind Article #2409   (Valid Article)
#  - Loadind Article #2410   (Valid Article)
#  - Loadind Article #2411   (Valid Article)
#  - Loadind Article #2412   (Valid Article)
#  - Loadind Article #2413   (Valid Article)
#  - Loadind Article #2414   (Valid Article)
#  - Loadind Article #2415   (Valid Article)
#  - Loadind Article #2416   (Valid Article)
#  - Loadind Article #2417   (Valid Article)
#  - Loadind Article #2418   (Valid Article)
#  - Loadind Article #2419   (Valid Article)
#  - Loadind Article #2420   (Valid Article)
#  - Loadind Article #2421   (Valid Article)
#  - Loadind Article #2422   (Not valid : Text empty)
#  - Loadind Article #2423   (Valid Article)
#  - Loadind Article #2424   (Valid Article)
#  - Loadind Article #2425   (Valid Article)
#  - Loadind Article #2426   (Valid Article)
#  - Loadind Article #2427   (Valid Article)
#  - Loadind Article #2428   (Valid Article)
#  - Loadind Article #2429   (Valid Article)
#  - Loadind Article #2430   (Valid Article)
#  - Loadind Article #2431   (Valid Article)
#  - Loadind Article #2432   (Valid Article)
#  - Loadind Article #2433   (Valid Article)
#  - Loadind Article #2434   (Valid Article)
#  - Loadind Article #2435   (Valid Article)
#  - Loadind Article #2436   (Valid Article)
#  - Loadind Article #2437   (Valid Article)
#  - Loadind Article #2438   (Valid Article)
#  - Loadind Article #2439   (Valid Article)
#  - Loadind Article #2440   (Valid Article)
#  - Loadind Article #2441   (Valid Article)
#  - Loadind Article #2442   (Valid Article)
#  - Loadind Article #2443   (Valid Article)
#  - Loadind Article #2444   (Valid Article)
#  - Loadind Article #2445   (Valid Article)
#  - Loadind Article #2446   (Valid Article)
#  - Loadind Article #2447   (Valid Article)
#  - Loadind Article #2448   (Valid Article)
#  - Loadind Article #2449   (Valid Article)
#  - Loadind Article #2450   (Valid Article)
#  - Loadind Article #2451   (Valid Article)
#  - Loadind Article #2452   (Valid Article)
#  - Loadind Article #2453   (Not valid : Dict could not be read)
#  - Loadind Article #2454   (Not valid : Text empty)
#  - Loadind Article #2455   (Valid Article)
#  - Loadind Article #2456   (Valid Article)
#  - Loadind Article #2457   (Valid Article)
#  - Loadind Article #2458   (Valid Article)
#  - Loadind Article #2459   (Not valid : Text empty)
#  - Loadind Article #2460   (Not valid : Dict could not be read)
#  - Loadind Article #2461   (Valid Article)
#  - Loadind Article #2462   (Not valid : Dict could not be read)
#  - Loadind Article #2463   (Not valid : Text empty)
#  - Loadind Article #2464   (Not valid : Text empty)
#  - Loadind Article #2465   (Not valid : Dict could not be read)
#  - Loadind Article #2466   (Not valid : Dict could not be read)
#  - Loadind Article #2467   (Valid Article)
#  - Loadind Article #2468   (Valid Article)
#  - Loadind Article #2469   (Not valid : Text empty)
#  - Loadind Article #2470   (Not valid : Text empty)
